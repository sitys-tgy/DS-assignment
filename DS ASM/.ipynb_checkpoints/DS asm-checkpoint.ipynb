# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Data Libraries

# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Data

# %%
#HRA = pd.concat(map(pd.read_csv, ["aug_train.csv", "aug_test.csv"]), ignore_index=True)
#HRA.tail()
missing_value_formats = ["n.a.","?","NA","NaN","n/a", "na", "--"," "]
HRA= pd.read_csv('aug_train.csv',na_values=missing_value_formats)

# %% [markdown]
# ### Renamed data columns

# %%
train_data = HRA.rename(
columns={'enrollee_id':'Draftee_ID',
        'city':'City_Code',
        'city_development_index':'City_Dev_Index',
        'gender':'Gender',
        'relevent_experience':'Relevant_Experience',
        'enrolled_university':'Drafteed_University',
        'education_level':'Education_Level',
        'major_discipline':'Major_Discipline',
        'experience':'Experience_Year',
        'company_size':'Agency_Size',
        'company_type':'Agency_Type',
        'last_new_job':'Pre_Employment_Duration',
        'training_hours':'Training_Hours',})

# %% [markdown]
# ### Exploratory Analysis

# %%
train_data.head(10)
# Out:
#    Draftee_ID City_Code  City_Dev_Index Gender      Relevant_Experience  \
# 0        8949  city_103           0.920   Male  Has relevent experience
# 1       29725   city_40           0.776   Male   No relevent experience
# 2       11561   city_21           0.624    NaN   No relevent experience
# 3       33241  city_115           0.789    NaN   No relevent experience
# 4         666  city_162           0.767   Male  Has relevent experience
# 5       21651  city_176           0.764    NaN  Has relevent experience
# 6       28806  city_160           0.920   Male  Has relevent experience
# 7         402   city_46           0.762   Male  Has relevent experience
# 8       27107  city_103           0.920   Male  Has relevent experience
# 9         699  city_103           0.920    NaN  Has relevent experience
#
#   Drafteed_University Education_Level Major_Discipline Experience_Year  \
# 0       no_enrollment        Graduate             STEM             >20
# ...

# %%
train_data.describe()
# Out:
#          Draftee_ID  City_Dev_Index  Training_Hours        target
# count  19158.000000    19158.000000    19158.000000  19158.000000
# mean   16875.358179        0.828848       65.366896      0.249348
# std     9616.292592        0.123362       60.058462      0.432647
# min        1.000000        0.448000        1.000000      0.000000
# 25%     8554.250000        0.740000       23.000000      0.000000
# 50%    16982.500000        0.903000       47.000000      0.000000
# 75%    25169.750000        0.920000       88.000000      0.000000
# max    33380.000000        0.949000      336.000000      1.000000

# %%
train_data_categorical = train_data.select_dtypes(include='object')
train_data_categorical.describe()
# Out:
#        City_Code Gender      Relevant_Experience Drafteed_University  \
# count      19158  14650                    19158               18772
# unique       123      3                        2                   3
# top     city_103   Male  Has relevent experience       no_enrollment
# freq        4355  13221                    13792               13817
#
#        Education_Level Major_Discipline Experience_Year Agency_Size  \
# count            18698            16345           19093       13220
# unique               5                6              22           8
# top           Graduate             STEM             >20       50-99
# freq             11598            14492            3286        3083
#
#        Agency_Type Pre_Employment_Duration
# count        13018                   18735
# unique           6                       6
# top        Pvt Ltd                       1
# freq          9817                    8040

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Draftee_ID               19158 non-null  int64
#  1   City_Code                19158 non-null  object
#  2   City_Dev_Index           19158 non-null  float64
#  3   Gender                   14650 non-null  object
#  4   Relevant_Experience      19158 non-null  object
#  5   Drafteed_University      18772 non-null  object
#  6   Education_Level          18698 non-null  object
#  7   Major_Discipline         16345 non-null  object
#  8   Experience_Year          19093 non-null  object
#  9   Agency_Size              13220 non-null  object
#  10  Agency_Type              13018 non-null  object
#  11  Pre_Employment_Duration  18735 non-null  object
#  12  Training_Hours           19158 non-null  int64
#  13  target                   19158 non-null  float64
# ...

# %%
plt.figure(figsize=[8,20])
plt.subplots_adjust(hspace=2)
plt.subplot(7,1,1)

sns.countplot(x='Relevant_Experience', hue='Education_Level', edgecolor="black", alpha=0.7, data=train_data)
sns.despine()
plt.title("Countplot of Relevant Experience by Education Level")
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=[8,20])
plt.subplots_adjust(hspace=2)
plt.subplot(7,1,2)

sns.countplot(x='Gender', hue='Relevant_Experience', edgecolor="black", alpha=0.7, data=train_data)
sns.despine()
plt.title("Countplot of Gender by Relevant Experience")
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=[8,30])
plt.subplots_adjust(hspace=2)
plt.subplot(7,1,3)

sns.countplot(x='Drafteed_University', hue='Major_Discipline', edgecolor="black", alpha=0.7, data=train_data)
sns.despine()
plt.title("Countplot of Drafteed University by Major Discipline")
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=[8,30])
plt.subplots_adjust(hspace=2)
plt.subplot(7,1,4)

sns.countplot(x='Relevant_Experience', hue='Major_Discipline', edgecolor="black", alpha=0.7, data=train_data)
sns.despine()
plt.title("Countplot of Relevent Experience by Education Level")
    
plt.tight_layout()
plt.show()

# %%
df_countplot = train_data[['Gender', 'Relevant_Experience', 'Drafteed_University', 'Education_Level', 'Major_Discipline', 'Experience_Year', 'Agency_Size', 'Agency_Type', 'Pre_Employment_Duration']]   

for i in df_countplot:
    plt.figure(figsize=(12,6.5)) 
    plt.title(i, fontsize=15, fontweight='bold', ha='center')
    sns.countplot(data = train_data[i], x = df_countplot[i], palette= sns.color_palette("tab10"))
    plt.show()

# %%
print('Total missing value in dataset:\n', train_data.isna().sum())
# Out:
# Total missing value in dataset:
#  Draftee_ID                    0
# City_Code                     0
# City_Dev_Index                0
# Gender                     4508
# Relevant_Experience           0
# Drafteed_University         386
# Education_Level             460
# Major_Discipline           2813
# Experience_Year              65
# Agency_Size                5938
# Agency_Type                6140
# Pre_Employment_Duration     423
# Training_Hours                0
# target                        0
# dtype: int64

# %%
plt.figure(figsize=(12,6.5))
plt.title("Target", fontsize=15, fontweight='bold', ha='center')
sns.countplot(data=train_data, x='target')
# Out:
# <AxesSubplot:title={'center':'Target'}, xlabel='target', ylabel='count'>

# %% [markdown]
# ### Data cleaning

# %%
data=train_data
data.shape
# Out:
# (19158, 14)

# %%
data['City_Code'] = data['City_Code'].str.split("_",expand=True)[1].astype('int64')

col_with_nan = ['Gender', 'Drafteed_University', 'Education_Level','Major_Discipline','Experience_Year','Agency_Size','Agency_Type','Pre_Employment_Duration']

for i in col_with_nan:
    data[i] = data[i].fillna(data[i].mode()[0])

# %%
data = data[data.Gender != 'Other']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18967 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Draftee_ID               18967 non-null  int64
#  1   City_Code                18967 non-null  int64
#  2   City_Dev_Index           18967 non-null  float64
#  3   Gender                   18967 non-null  object
#  4   Relevant_Experience      18967 non-null  object
#  5   Drafteed_University      18967 non-null  object
#  6   Education_Level          18967 non-null  object
#  7   Major_Discipline         18967 non-null  object
#  8   Experience_Year          18967 non-null  object
#  9   Agency_Size              18967 non-null  object
#  10  Agency_Type              18967 non-null  object
#  11  Pre_Employment_Duration  18967 non-null  object
#  12  Training_Hours           18967 non-null  int64
#  13  target                   18967 non-null  float64
# ...

# %%
le = LabelEncoder()

data['Gender']= le.fit_transform(data['Gender'])
data['Relevant_Experience']= le.fit_transform(data['Relevant_Experience'])
data['Drafteed_University']= le.fit_transform(data['Drafteed_University'])
data['Education_Level']= le.fit_transform(data['Education_Level'])
data['Major_Discipline']= le.fit_transform(data['Major_Discipline'])
data['Experience_Year']= le.fit_transform(data['Experience_Year'])
data['Agency_Size']= le.fit_transform(data['Agency_Size'])
data['Agency_Type']= le.fit_transform(data['Agency_Type'])
data['Pre_Employment_Duration']= le.fit_transform(data['Pre_Employment_Duration'])
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11964/3590194496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender']= le.fit_transform(data['Gender'])
# C:\Users\User\AppData\Local\Temp/ipykernel_11964/3590194496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Relevant_Experience']= le.fit_transform(data['Relevant_Experience'])
# C:\Users\User\AppData\Local\Temp/ipykernel_11964/3590194496.py:5: SettingWithCopyWarning:
# ...

# %%
data.head()
# Out:
#    Draftee_ID  City_Code  City_Dev_Index  Gender  Relevant_Experience  \
# 0        8949        103           0.920       1                    0
# 1       29725         40           0.776       1                    1
# 2       11561         21           0.624       1                    1
# 3       33241        115           0.789       1                    1
# 4         666        162           0.767       1                    0
#
#    Drafteed_University  Education_Level  Major_Discipline  Experience_Year  \
# 0                    2                0                 5               21
# 1                    2                0                 5                6
# 2                    0                0                 5               15
# 3                    2                0                 1               20
# 4                    2                2                 5               21
#
#    Agency_Size  Agency_Type  Pre_Employment_Duration  Training_Hours  target
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot = True, color='b')
# Out:
# <AxesSubplot:>

# %%
X = data.drop(columns='target')
Y = data['target']

over = SMOTE(random_state=42)
X_smote, Y_smote = over.fit_resample(X,Y)

# %%
Y_smote.value_counts()
# Out:
# 1.0    14240
# 0.0    14240
# Name: target, dtype: int64

# %%
from seaborn import boxplot
boxplot(data=train_data[['Draftee_ID','City_Dev_Index','Training_Hours']], palette='Set3')
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
boxplt1 = sns.boxplot(train_data['Draftee_ID'], ax = axs[0],color='green')
boxplt2 = sns.boxplot(train_data['City_Dev_Index'], ax = axs[1],color='blue')
boxplt3 = sns.boxplot(train_data['Training_Hours'], ax = axs[2],color='cyan')

plt.tight_layout()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Data splitting

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_smote,Y_smote,shuffle=True,random_state=42)
